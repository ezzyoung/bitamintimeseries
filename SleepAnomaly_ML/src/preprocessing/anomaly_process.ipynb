# %%
# 📄 src/preprocessing/anomaly_preprocess.py

import os
import numpy as np
from scipy.io import loadmat

def preprocess_mat_folder(folder_path, selected_channels, save_path, label, augment_times=1):
    X_all = []
    y_all = []

    for fname in sorted(os.listdir(folder_path)):
        if not fname.endswith(".mat"):
            continue

        file_path = os.path.join(folder_path, fname)
        mat_data = loadmat(file_path)

        signals = []
        for ch in selected_channels:
            if ch not in mat_data:
                print(f"⚠️ {ch} not found in {fname}")
                continue
            signals.append(mat_data[ch])  # shape: (epochs, time)

        if len(signals) != len(selected_channels):
            print(f"❌ Skipping {fname} due to missing channels")
            continue

        data = np.stack(signals, axis=1)  # (epochs, channels, time)

        # Z-score normalize
        for c in range(data.shape[1]):
            ch_data = data[:, c, :]
            mean = np.mean(ch_data)
            std = np.std(ch_data) + 1e-6
            data[:, c, :] = (ch_data - mean) / std

        labels = np.full((data.shape[0],), label)

        # ✅ 데이터 보강 (특히 정상 데이터용)
        for i in range(augment_times):
            X_all.append(data.copy())
            y_all.append(labels.copy())

        print(f"✅ {fname} → {data.shape} x {augment_times} 회 누적")

    X_all = np.concatenate(X_all, axis=0)
    y_all = np.concatenate(y_all, axis=0)

    os.makedirs(save_path, exist_ok=True)
    np.save(os.path.join(save_path, f'X_label{label}.npy'), X_all)
    np.save(os.path.join(save_path, f'y_label{label}.npy'), y_all)
    print(f"📁 Saved to {save_path} | X: {X_all.shape}, y: {y_all.shape}")

if __name__ == "__main__":
    selected_channels = ['F3_A2', 'C3_A2', 'O1_A2', 'F4_A1', 'C4_A1',
                         'O2_A1', 'LOC_A2', 'ROC_A1', 'X1', 'X2']

    # ✅ 정상 데이터 10배 보강
    preprocess_mat_folder("../../Database/raw/Healthy_Subjects", selected_channels, "../../Database/processed", label=0, augment_times=10)
    preprocess_mat_folder("../../Database/raw/Unhealthy_Subjects", selected_channels, "../../Database/processed", label=1, augment_times=1)
# Out:
# ✅ subject1.mat → (924, 10, 6000) x 10 회 누적
# ✅ subject10.mat → (766, 10, 6000) x 10 회 누적
# ✅ subject2.mat → (911, 10, 6000) x 10 회 누적
# ✅ subject3.mat → (794, 10, 6000) x 10 회 누적
# ✅ subject4.mat → (764, 10, 6000) x 10 회 누적
# ✅ subject5.mat → (914, 10, 6000) x 10 회 누적
# ✅ subject6.mat → (823, 10, 6000) x 10 회 누적
# ✅ subject7.mat → (784, 10, 6000) x 10 회 누적
# ✅ subject8.mat → (970, 10, 6000) x 10 회 누적
# ✅ subject9.mat → (939, 10, 6000) x 10 회 누적
# 📁 Saved to ../../Database/processed | X: (85890, 10, 6000), y: (85890,)
# ✅ subject1.mat → (850, 10, 6000) x 1 회 누적
# ✅ subject10.mat → (812, 10, 6000) x 1 회 누적
# ✅ subject100.mat → (831, 10, 6000) x 1 회 누적
# ✅ subject11.mat → (967, 10, 6000) x 1 회 누적
# ✅ subject12.mat → (820, 10, 6000) x 1 회 누적
# ✅ subject13.mat → (852, 10, 6000) x 1 회 누적
# ✅ subject14.mat → (876, 10, 6000) x 1 회 누적
# ✅ subject15.mat → (756, 10, 6000) x 1 회 누적
# ✅ subject16.mat → (853, 10, 6000) x 1 회 누적
# ✅ subject17.mat → (821, 10, 6000) x 1 회 누적
# ✅ subject18.mat → (969, 10, 6000) x 1 회 누적
# ✅ subject19.mat → (798, 10, 6000) x 1 회 누적
# ✅ subject2.mat → (934, 10, 6000) x 1 회 누적
# ✅ subject20.mat → (920, 10, 6000) x 1 회 누적
# ✅ subject21.mat → (1024, 10, 6000) x 1 회 누적
# ✅ subject22.mat → (819, 10, 6000) x 1 회 누적
# ✅ subject23.mat → (862, 10, 6000) x 1 회 누적
# ✅ subject24.mat → (800, 10, 6000) x 1 회 누적
# ✅ subject25.mat → (891, 10, 6000) x 1 회 누적
# ✅ subject26.mat → (1032, 10, 6000) x 1 회 누적
# ✅ subject27.mat → (888, 10, 6000) x 1 회 누적
# ✅ subject28.mat → (852, 10, 6000) x 1 회 누적
# ✅ subject29.mat → (882, 10, 6000) x 1 회 누적
# ✅ subject3.mat → (913, 10, 6000) x 1 회 누적
# ✅ subject30.mat → (852, 10, 6000) x 1 회 누적
# ✅ subject31.mat → (847, 10, 6000) x 1 회 누적
# ✅ subject32.mat → (980, 10, 6000) x 1 회 누적
# ✅ subject33.mat → (890, 10, 6000) x 1 회 누적
# ✅ subject34.mat → (841, 10, 6000) x 1 회 누적
# ✅ subject35.mat → (758, 10, 6000) x 1 회 누적
# ✅ subject36.mat → (957, 10, 6000) x 1 회 누적
# ✅ subject37.mat → (776, 10, 6000) x 1 회 누적
# ✅ subject38.mat → (902, 10, 6000) x 1 회 누적
# ✅ subject39.mat → (870, 10, 6000) x 1 회 누적
# ✅ subject4.mat → (933, 10, 6000) x 1 회 누적
# ✅ subject40.mat → (845, 10, 6000) x 1 회 누적
# ✅ subject41.mat → (944, 10, 6000) x 1 회 누적
# ✅ subject42.mat → (782, 10, 6000) x 1 회 누적
# ✅ subject43.mat → (717, 10, 6000) x 1 회 누적
# ✅ subject44.mat → (902, 10, 6000) x 1 회 누적
# ✅ subject45.mat → (876, 10, 6000) x 1 회 누적
# ✅ subject46.mat → (833, 10, 6000) x 1 회 누적
# ✅ subject47.mat → (808, 10, 6000) x 1 회 누적
# ✅ subject48.mat → (951, 10, 6000) x 1 회 누적
# ✅ subject49.mat → (763, 10, 6000) x 1 회 누적
# ✅ subject5.mat → (845, 10, 6000) x 1 회 누적
# ✅ subject50.mat → (875, 10, 6000) x 1 회 누적
# ✅ subject51.mat → (826, 10, 6000) x 1 회 누적
# ✅ subject52.mat → (882, 10, 6000) x 1 회 누적
# ✅ subject53.mat → (880, 10, 6000) x 1 회 누적
# ✅ subject54.mat → (784, 10, 6000) x 1 회 누적
# ✅ subject55.mat → (849, 10, 6000) x 1 회 누적
# ✅ subject56.mat → (926, 10, 6000) x 1 회 누적
# ✅ subject57.mat → (977, 10, 6000) x 1 회 누적
# ✅ subject58.mat → (935, 10, 6000) x 1 회 누적
# ✅ subject59.mat → (912, 10, 6000) x 1 회 누적
# ✅ subject6.mat → (867, 10, 6000) x 1 회 누적
# ✅ subject60.mat → (886, 10, 6000) x 1 회 누적
# ✅ subject61.mat → (822, 10, 6000) x 1 회 누적
# ✅ subject62.mat → (834, 10, 6000) x 1 회 누적
# ✅ subject63.mat → (924, 10, 6000) x 1 회 누적
# ✅ subject64.mat → (862, 10, 6000) x 1 회 누적
# ✅ subject65.mat → (984, 10, 6000) x 1 회 누적
# ✅ subject66.mat → (815, 10, 6000) x 1 회 누적
# ✅ subject67.mat → (832, 10, 6000) x 1 회 누적
# ✅ subject68.mat → (926, 10, 6000) x 1 회 누적
# ✅ subject69.mat → (785, 10, 6000) x 1 회 누적
# ✅ subject7.mat → (903, 10, 6000) x 1 회 누적
# ✅ subject70.mat → (863, 10, 6000) x 1 회 누적
# ✅ subject71.mat → (799, 10, 6000) x 1 회 누적
# ✅ subject72.mat → (842, 10, 6000) x 1 회 누적
# ✅ subject73.mat → (967, 10, 6000) x 1 회 누적
# ✅ subject74.mat → (867, 10, 6000) x 1 회 누적
# ✅ subject75.mat → (868, 10, 6000) x 1 회 누적
# ✅ subject76.mat → (820, 10, 6000) x 1 회 누적
# ✅ subject77.mat → (775, 10, 6000) x 1 회 누적
# ✅ subject78.mat → (864, 10, 6000) x 1 회 누적
# ✅ subject79.mat → (850, 10, 6000) x 1 회 누적
# ✅ subject8.mat → (874, 10, 6000) x 1 회 누적
# ✅ subject80.mat → (859, 10, 6000) x 1 회 누적
# ✅ subject81.mat → (881, 10, 6000) x 1 회 누적
# ✅ subject82.mat → (852, 10, 6000) x 1 회 누적
# ✅ subject83.mat → (895, 10, 6000) x 1 회 누적
# ✅ subject84.mat → (933, 10, 6000) x 1 회 누적
# ✅ subject85.mat → (866, 10, 6000) x 1 회 누적
# ✅ subject86.mat → (934, 10, 6000) x 1 회 누적
# ✅ subject87.mat → (896, 10, 6000) x 1 회 누적
# ✅ subject88.mat → (972, 10, 6000) x 1 회 누적
# ✅ subject89.mat → (1006, 10, 6000) x 1 회 누적
# ✅ subject9.mat → (939, 10, 6000) x 1 회 누적
# ✅ subject90.mat → (903, 10, 6000) x 1 회 누적
# ✅ subject91.mat → (960, 10, 6000) x 1 회 누적
# ✅ subject92.mat → (847, 10, 6000) x 1 회 누적
# ✅ subject93.mat → (840, 10, 6000) x 1 회 누적
# ✅ subject94.mat → (816, 10, 6000) x 1 회 누적
# ✅ subject95.mat → (835, 10, 6000) x 1 회 누적
# ✅ subject96.mat → (828, 10, 6000) x 1 회 누적
# ✅ subject97.mat → (882, 10, 6000) x 1 회 누적
# ✅ subject98.mat → (869, 10, 6000) x 1 회 누적
# ✅ subject99.mat → (805, 10, 6000) x 1 회 누적
# 📁 Saved to ../../Database/processed | X: (87187, 10, 6000), y: (87187,)
